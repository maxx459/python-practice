# %%
# 1. Write a python program to add two numbers.

print("Addition")
a=int(input("Enter 1st number:"))
b=int(input("Enter 2st number:"))
print("Sum of two numbers",a+b)
# Out:
# Addition
# Sum of two numbers 5

# %%
# 2. Write a python program to find remainder when a number is divided by z. 

print("Remainder")
a=int(input("Enter 1st number:"))
b=int(input("Enter 2st number:"))
print("remainder for two numbers",a%b)
# Out:
# Remainder
# Sum of two numbers 0

# %%
# 3. Check the type of variable assigned using input () function.
a=input("enter a value")
print(type(a))
print(type(int(a)))
print(type(float(a)))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
# 4. Use comparison operator to find out whether ‘a’ given variable a is greater than 
# ‘b’ or not. Take a = 34 and b = 80 

a=int(input("Enter 1st number:"))
b=int(input("Enter 2st number:"))

print("Is 'a' is greater than 'b': ", a>b)
# Out:
# Is 'a' is greater than 'b':  False

# %%
# 5. Write a python program to find an average of two numbers entered by the user.

a=int(input("Enter 1st number:"))
b=int(input("Enter 2st number:"))

c= (a+b)/2

print("Average of two numbers: ",c)
# Out:
# Average of two numbers:  3.5

# %%
# 6. Write a python program to calculate the square of a number entered by the user.

import math

a=int(input("Enter a number:"))
b=a*a
c=a**2
d=pow(a,2)
f=math.pow(a,2)

print("square of the give number: ",b)
print(c)
print(d)
print(f)
# Out:
# square of the give number:  4
# 4
# 4
# 4.0
