# %% [markdown]
# CHAPTER 5  – PRACTICE SET
# 1. Write a program to create a dictionary of Hindi words with values as their English
# translation. Provide user with an option to look it up!
# 2. Write a program to input eight numbers from the user and display all the unique
# numbers (once).
# 3. Can we have a set with 18 (int) and '18' (str) as a value in it?
# 4. What will be the length of following set s:
# s = set()
# s.add(20)
# s.add(20.0)
# s.add('20') # length of s after these operations?
# 5. s = {}
# What is the type of 's'?
# 6. Create an empty dictionary. Allow 4 friends to enter their favorite language as
# value and use key as their names. Assume that the names are unique.
# 7. If the names of 2 friends are same; what will happen to the program in problem
# 6?
# 8. If languages of two friends are same; what will happen to the program in problem
# 6?
# 9. Can you change the values inside a list which is contained in set S?
# s = {8, 7, 12, "Harry", [1,2]}

# %%
#1 answer
hinglish_dict = {
    "kya": "what",
    "kaise": "how",
    "kyun": "why",
    "kab": "when",
    "kahan": "where",
    "kaun": "who",
    "haan": "yes",
    "nahi": "no",
    "achha": "good",
    "theek": "okay",
    "jaldi": "quickly",
    "baad mein": "later",
    "abhi": "now",
    "ghar": "home",
    "dost": "friend",
    "bhai": "brother",
    "behen": "sister",
    "paani": "water",
    "khana": "food",
    "sona": "sleep",
    "padhna": "study",
    "kaam": "work",
    "madad": "help",
    "samajh": "understand",
    "intezaar": "wait",
    "milte hain": "see you",
    "dhanyavaad": "thank you",
    "shukriya": "thanks",
    "maaf karo": "sorry",
    "ruk": "stop",
    "chalo": "let's go"
}

lookup=input("enter a hindi word for english translation:")
print("engish word:",hinglish_dict.get(lookup))
# Out:
# engish word: what

# %%
#2

user=set()
print("Enter eight numbers:")
for i in range(8):
    user.add(int(input("{i}:")))
print(user)
# Out:
# Enter eight numbers:
# {1, 2, 3, 4, 5}

# %%
#3 answer

# import random
# import string

# num=random.randint(1,200)# generate single random integer
# set1=set(random.sample(range(1,200),18))# generate sample of integers based on the our requirement
# set2=set()
# for i in range(18):
#     # set2.add("".join(random.choices(string.ascii_lowercase,k=5)))
#     temp="".join(random.choices(string.ascii_lowercase,k=5))
#     # print(type(temp)) # output:<class 'str'>
#     set2.add(temp)

# print(set1)
# print(set2)
# print(set1.union(set2))

#output
# {160, 129, 33, 165, 166, 8, 140, 109, 111, 144, 82, 83, 52, 23, 87, 184, 153, 159}
# {'nyaho', 'edtbl', 'acwks', 'mbnup', 'smequ', 'wuhgi', 'nbqrg', 'dpfte', 'wilhu', 'olxzd', 'iungj', 'nzeai', 'jyies', 'qgzjt', 'hltqh', 'btkdm', 'ahzky', 'zajkj'}
# {'nyaho', 129, 8, 'wuhgi', 'nbqrg', 140, 144, 'iungj', 82, 83, 'nzeai', 'jyies', 23, 87, 153, 'qgzjt', 'hltqh', 'ahzky', 159, 160, 33, 'edtbl', 'acwks', 'mbnup', 165, 166, 'smequ', 'dpfte', 109, 111, 'olxzd', 52, 184, 'btkdm', 'wilhu', 'zajkj'}

set1=set()
set1.add(18)
set1.add(18.0)
set1.add("18")
print(set1)
# Out:
# {18, '18'}

# %%
#4 answer

s = set() 
s.add(20) 
s.add(20.0) 
s.add(20.2) 
s.add('20') # length of s after these operations?

print(len(s))
print(s)
# Out:
# 3
# {'20', 20, 20.2}

# %%
#5 answer
s={}
print(type(s))
# Out:
# <class 'dict'>

# %%
#6 answer
line=int(input("enter the number of people:\n"))
people={}
for i in range(line):
    name=input("enter your name")
    lang=input("enter your favorite language:")
    # people[name] = lang #one way to do it
    people.update({name: lang})# second way to do it 
   
print(people)
# Out:
# {'charan': 'en', 'jaggu': 'telugu', 'sury': 'eng', 'naveen': 'en'}

# %%
#7 answer

line=int(input("enter the number of people:\n"))
people={}
for i in range(line):
    name=input("enter your name")
    lang=input("enter your favorite language:")
    people.update({name: lang})
   
print(people)
#input: {'charan': 'en', 'jaggu': 'tel', 'sury': 'hindi', 'sury': 'en'}
#output: {'charan': 'en', 'jaggu': 'tel', 'sury': 'en'}
# Out:
# {'charan': 'en', 'jaggu': 'tel', 'sury': 'en'}

# %%
#8 answer

line=int(input("enter the number of people:\n"))
people={}
for i in range(line):
    name=input("enter your name")
    lang=input("enter your favorite language:")
    people.update({name: lang})
   
print(people)
#input: {'charan': 'en', 'jaggu': 'tel', 'ram': 'hindi', 'sury': 'en'}
#output: {'charan': 'en', 'jaggu': 'tel', 'ram': 'hindi', 'sury': 'en'}
# Out:
# {'charan': 'en', 'jaggu': 'tel', 'ram': 'hindi', 'sury': 'en'}

# %%
# 9 answer

#we can't directly replace the list but we can do as follow if 

# s = {8, 7, 12, "Harry", [1,2]}

# s.remove([1,2])
# s.add([1,2,3,4])
# print(s)    #lol i didn't we can't store list inside a set

#chatgpt answer:
# No, you cannot change the values inside a list contained in a set in Python. In fact, you cannot even
# have a list as an element in a set because sets in Python require all their elements to be immutable
# and hashable. Lists are mutable and not hashable, so they cannot be added to a set.

#To achieve similar functionality, you might consider using a tuple instead of a list because tuples are
# immutable and hashable:

s = {8, 7, 12, "Harry", (1, 2)}

s.remove((1,2))
s.add((1,2,3,4))
print(s)
# Out:
# {(1, 2, 3, 4), 'Harry', 7, 8, 12}
